# %% [markdown]
# # Machine Learning

# %% [markdown]
# Humans are really good a finding patterns. Even from a young age, they can group together items that are similar. Grouping similar things is an essential step in learning concepts, even before language comes into play.
#
# In machine learning, we do things like find *similar things*, *classify*, *predict*, *generate*, and more.
#
# Today we'll learn about things called "features", measuring the difference between things, and finding similarities!

# %% [markdown]
# # In Daily Life...

# %% [markdown]
# Machine learning today has taken off thanks to the large amounts of data available, thanks to the internet. One example includes Netflix being able to suggest new shows that you might like.
#
# Let's explore this idea more. The main concept behind it is that you might like things that are similar to what you already like. This has some caveats (we'll talk about it in the Ethics for AI section), but it is behind much of the technology we have around us today.

# %% [markdown]
# # Let's talk about music.

# %% [markdown]
# Imagine that we want to make an AI program that suggests new song that you might like. Let's say you are interested in discovering songs that you like from other countries, or in other languages.
#
# But how do you quantify or measure what you like? Could you even describe it?
#
# Let's explore the Spotify Dataset 2017 songs of 2017 to learn how an algorithm to suggest new songs might work.
#
# Consider this dataset:

# %%
import pandas
data = pandas.read_csv('data/spotify.csv')  # Top 2017 songs of 2017 from kaggle.com

# %%
data
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0      0.010200         0.833       204600   0.434
# 1              1      0.199000         0.743       326933   0.359
# 2              2      0.034400         0.838       185707   0.412
# 3              3      0.604000         0.494       199413   0.338
# 4              4      0.180000         0.678       392893   0.561
# 5              5      0.004790         0.804       251333   0.560
# 6              6      0.014500         0.739       241400   0.472
# 7              7      0.020200         0.266       349667   0.348
# 8              8      0.048100         0.603       202853   0.944
# 9              9      0.002080         0.836       226840   0.603
# 10            10      0.057200         0.525       358187   0.855
# 11            11      0.091500         0.753       324880   0.748
# 12            12      0.253000         0.603       356973   0.434
# 13            13      0.366000         0.762       243270   0.476
# 14            14      0.440000         0.662       247288   0.603
# 15            15      0.019000         0.637       188333   0.832
# 16            16      0.023900         0.603       270827   0.955
# 17            17      0.233000         0.789       447907   0.659
# 18            18      0.314000         0.713       195429   0.611
# 19            19      0.024200         0.735       214347   0.759
# 20            20      0.000702         0.854       249253   0.719
# 21            21      0.000240         0.747       307680   0.740
# 22            22      0.118000         0.854       287086   0.401
# 23            23      0.000596         0.224       132760   0.925
# 24            24      0.279000         0.512       203400   0.564
# 25            25      0.002190         0.781       205160   0.795
# 26            26      0.341000         0.411       199500   0.684
# 27            27      0.018000         0.646       188333   0.837
# 28            28      0.051600         0.782       228562   0.572
# 29            29      0.282000         0.735       186096   0.400
# ...          ...           ...           ...          ...     ...
# 1987        1987      0.028300         0.421       175907   0.831
# 1988        1988      0.000084         0.467       209187   0.794
# 1989        1989      0.000797         0.480       222053   0.826
# 1990        1990      0.000590         0.594       218720   0.858
# 1991        1991      0.000366         0.544       245133   0.788
# 1992        1992      0.007490         0.446       241253   0.881
# 1993        1993      0.001900         0.551       195280   0.732
# 1994        1994      0.510000         0.630       240000   0.772
# 1995        1995      0.020200         0.333       174240   0.913
# 1996        1996      0.003630         0.743       259889   0.889
# 2003                                       Hold Up                   Borgeous
# 2004              Phone Down - Dodge & Fuski Remix                 Lost Kings
# 2005                      Spoon Me - Slushii Remix                  Elliphant
# 2006             Scared To Be Lonely (Conro Remix)              Martin Garrix
# 2007  Let It Go - Scott Melker & Mister Gray Remix                      NERVO
# 2008     Call On Me - EDWYNN X TIKAL, Spirix Remix                    Starley
# 2009                                         Aamon                      Kuuro
# 2010                   Hey Baby - Steve Aoki Remix  Dimitri Vegas & Like Mike
# 2011                   Brightside - Borgeous Remix                  Icona Pop
# 2012           Like A Bitch - Kill The Noise Remix             Kill The Noise
# 2013                                         Candy             Dillon Francis
# 2014          Habit - Dack Janiels & Wenzday Remix                   Rain Man
# 2015                                 First Contact                 Twin Moons
# 2016                            I Wanna Get Better                  Bleachers
#
# [2017 rows x 17 columns]

# %%
# indexing example using .loc
for k in range(5):
    print(data.loc[k,["tempo","song_title"]])
# Out:
# tempo          150.062
# song_title    Mask Off
# Name: 0, dtype: object
# tempo         160.083
# song_title    Redbone
# Name: 1, dtype: object
# tempo               75.044
# song_title    Xanny Family
# Name: 2, dtype: object
# tempo                 86.468
# song_title    Master Of None
# Name: 3, dtype: object
# tempo                174.004
# song_title    Parallel Lines
# Name: 4, dtype: object

# %% [markdown]
# # Features

# %% [markdown]
# In this dataset of 2017 songs, you will see that, alongside every song title, there are many characteristics or **features** extracted for each song. These features include numerical information like tempo, acousticness, etc.

# %% [markdown]
# Imagine that you were to search this entire database for a song that you might like. Some features will be useful for finding similar songs. Which features do you think would be most useful? Least useful?

# %% [markdown]
# ## What can we do with Features?

# %% [markdown]
# Using features, we can already:
#
# - visualize our data, and
# - find similar items.
#
# We'll use a dataset to suggest songs that are similar to our favourite song. For the sake of this example, let's say that we like the song "Mask Off" by "Future" and would like to find songs that are similar. Let's just look at 2 features for now.

# %%
import pandas
raw_data = pandas.read_csv('data/spotify.csv')  # Top 2017 songs of 2017 from kaggle.com

# Just get the columns we want
dataset = pandas.DataFrame(raw_data, columns = ['tempo', 'acousticness', 'song_title', 'artist'])

# Let's just get the top 20 songs
dataset = dataset[:20]

# Display the dataset
dataset
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 1   160.083       0.19900                               Redbone
# 2    75.044       0.03440                          Xanny Family
# 3    86.468       0.60400                        Master Of None
# 4   174.004       0.18000                        Parallel Lines
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 7   144.154       0.02020                       Gyöngyhajú lány
# 8   130.035       0.04810                     I've Seen Footage
# 9    99.994       0.00208                        Digital Animal
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 12  127.681       0.25300                               Cemalim
# 13  130.007       0.36600                             One Night
# 14  125.011       0.44000                               Oh lala
# 15   99.988       0.01900                                  Char
# 16  123.922       0.02390                       World In Motion
# 17  122.415       0.23300             One Nation Under a Groove
# 18  140.061       0.31400                               Bouncin
# 19  109.982       0.02420                  C O O L - Radio Edit
#
#                 artist
# 0               Future
# 1     Childish Gambino
# 2               Future
# 3          Beach House
# 4          Junior Boys
# 5                Drake
# 6                Drake
# 7                Omega
# 8          Death Grips
# 9          Honey Claws
# 10      The Avalanches
# 11  Modern Folk Üçlüsü
# 12         Erkin Koray
# 13          Lil Yachty
# 14                 PNL
# 15     Crystal Castles
# 16           New Order
# 17          Funkadelic
# 18          Chief Keef
# 19            Le Youth

# %% [markdown]
# ## I want to find songs with a similar tempo!

# %% [markdown]
# Let's start by thinking about how to find similar songs if you only know one thing about each song, e.g. tempo.
# We'll compare each song to Mask Off.
#
# Let's add a new column that finds the differences in tempo from the top song, Mask Off (tempo=150.062)

# %%
abs(dataset.tempo - 100)
# Out:
# 0     50.062
# 1     60.083
# 2     24.956
# 3     13.532
# 4     74.004
# 5     14.977
# 6     19.970
# 7     44.154
# 8     30.035
# 9      0.006
# 10    11.951
# 11     4.322
# 12    27.681
# 13    30.007
# 14    25.011
# 15     0.012
# 16    23.922
# 17    22.415
# 18    40.061
# 19     9.982
# Name: tempo, dtype: float64

# %% [markdown]
# **Frome hereon we'll use the song Mask Off to calculate its distance to other songs**

# %%
# Add a column tempo_difference. 150.062 refers to Mask Off's tempo
#dataset['tempo_difference'] = abs(150.062 - dataset.tempo)
dataset['tempo_difference'] = abs(150.062 - dataset.tempo)
dataset
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 1   160.083       0.19900                               Redbone
# 2    75.044       0.03440                          Xanny Family
# 3    86.468       0.60400                        Master Of None
# 4   174.004       0.18000                        Parallel Lines
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 7   144.154       0.02020                       Gyöngyhajú lány
# 8   130.035       0.04810                     I've Seen Footage
# 9    99.994       0.00208                        Digital Animal
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 12  127.681       0.25300                               Cemalim
# 13  130.007       0.36600                             One Night
# 14  125.011       0.44000                               Oh lala
# 15   99.988       0.01900                                  Char
# 16  123.922       0.02390                       World In Motion
# 17  122.415       0.23300             One Nation Under a Groove
# 18  140.061       0.31400                               Bouncin
# 19  109.982       0.02420                  C O O L - Radio Edit
#
#                 artist  tempo_difference
# 0               Future             0.000
# 1     Childish Gambino            10.021
# 2               Future            75.018
# 3          Beach House            63.594
# 4          Junior Boys            23.942
# 5                Drake            65.039
# 6                Drake            70.032
# 7                Omega             5.908
# 8          Death Grips            20.027
# 9          Honey Claws            50.068
# 10      The Avalanches            38.111
# 11  Modern Folk Üçlüsü            45.740
# 12         Erkin Koray            22.381
# 13          Lil Yachty            20.055
# 14                 PNL            25.051
# 15     Crystal Castles            50.074
# 16           New Order            26.140
# 17          Funkadelic            27.647
# 18          Chief Keef            10.001
# 19            Le Youth            40.080

# %% [markdown]
# ## Let's visualize that

# %%
# Now let's visualize that 
# %matplotlib inline
import matplotlib.pyplot as plot
plot.rcParams["figure.figsize"] = 8,8

plot.scatter(dataset['tempo_difference'], dataset['song_title'])
#ax = plot.scatter(dataset['song_title'], dataset['tempo_difference'])
plot.xlabel('Absolute difference in Tempo')
plot.grid()
plot.show()

# %% [markdown]
# ## Now let's find how different they are in terms of acousticness!

# %%
# Add a new column that finds the differences in acousticness from top song, Mask Off (acousticness=0.01020)

dataset['acoustic_difference'] = abs(0.01020 - dataset.acousticness)
dataset
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 1   160.083       0.19900                               Redbone
# 2    75.044       0.03440                          Xanny Family
# 3    86.468       0.60400                        Master Of None
# 4   174.004       0.18000                        Parallel Lines
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 7   144.154       0.02020                       Gyöngyhajú lány
# 8   130.035       0.04810                     I've Seen Footage
# 9    99.994       0.00208                        Digital Animal
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 12  127.681       0.25300                               Cemalim
# 13  130.007       0.36600                             One Night
# 14  125.011       0.44000                               Oh lala
# 15   99.988       0.01900                                  Char
# 16  123.922       0.02390                       World In Motion
# 17  122.415       0.23300             One Nation Under a Groove
# 18  140.061       0.31400                               Bouncin
# 19  109.982       0.02420                  C O O L - Radio Edit
#
#                 artist  tempo_difference  acoustic_difference
# 0               Future             0.000              0.00000
# 1     Childish Gambino            10.021              0.18880
# 2               Future            75.018              0.02420
# 3          Beach House            63.594              0.59380
# 4          Junior Boys            23.942              0.16980
# 5                Drake            65.039              0.00541
# 6                Drake            70.032              0.00430
# 7                Omega             5.908              0.01000
# 8          Death Grips            20.027              0.03790
# 9          Honey Claws            50.068              0.00812
# 10      The Avalanches            38.111              0.04700
# 11  Modern Folk Üçlüsü            45.740              0.08130
# 12         Erkin Koray            22.381              0.24280
# 13          Lil Yachty            20.055              0.35580
# 14                 PNL            25.051              0.42980
# 15     Crystal Castles            50.074              0.00880
# 16           New Order            26.140              0.01370
# 17          Funkadelic            27.647              0.22280
# 18          Chief Keef            10.001              0.30380
# 19            Le Youth            40.080              0.01400

# %%
# Now let's visualize that with a histogram
import matplotlib.pyplot as plot

plot.scatter(dataset['acoustic_difference'], dataset['song_title'])

plot.xlabel('Difference in Acousticness')
plot.show()

# %% [markdown]
# ## Perceptually Similar Songs

# %% [markdown]
# If we manually look at which song looked the closest over both **tempo** and **acousticness** to Mask Off, we get ________________.
#
#
# Did you make your guess? Let's see if that sounds right!
#
# https://youtu.be/CGt-rTDkMcM
#
# https://youtu.be/xvZqHgFz51I

# %% [markdown]
# ## Visualizing The Songs in 2D Space

# %% [markdown]
# We can also visualize the two features simultaneously in a 2D plot, like this.

# %%
# Now let's visualize that by plotting all the original data points
import matplotlib.pyplot as plot
plot.rcParams["figure.figsize"] = 8,8

plot.scatter(dataset['tempo'], dataset['acousticness'])
plot.xlabel('Tempo')
plot.ylabel('Acousticness')

for index, row in dataset.iterrows():
    plot.annotate(str(row['song_title']), xy=(row['tempo'], row['acousticness']))
plot.grid()

# %% [markdown]
# # Calculating Distance in 2D Space

# %% [markdown]
# And now that we plot the songs in 2D space, we can properly calculate the distances in 2D mathematically, using the **Euclidean distance** function.

# %%
import numpy
dataset['euclidean_distance'] = numpy.sqrt( (0.01020 - dataset.acousticness)**2 + (150.062 - dataset.tempo)**2)

# Sort the dataset
sorted_dataset_distance = dataset.sort_values('euclidean_distance')

# Display sorted dataset
sorted_dataset_distance
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 7   144.154       0.02020                       Gyöngyhajú lány
# 18  140.061       0.31400                               Bouncin
# 1   160.083       0.19900                               Redbone
# 8   130.035       0.04810                     I've Seen Footage
# 13  130.007       0.36600                             One Night
# 12  127.681       0.25300                               Cemalim
# 4   174.004       0.18000                        Parallel Lines
# 14  125.011       0.44000                               Oh lala
# 16  123.922       0.02390                       World In Motion
# 17  122.415       0.23300             One Nation Under a Groove
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 19  109.982       0.02420                  C O O L - Radio Edit
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 9    99.994       0.00208                        Digital Animal
# 15   99.988       0.01900                                  Char
# 3    86.468       0.60400                        Master Of None
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 2    75.044       0.03440                          Xanny Family
#
#                 artist  tempo_difference  euclidean_distance
# 0               Future             0.000            0.000000
# 7                Omega             5.908            5.908008
# 18          Chief Keef            10.001           10.005613
# 1     Childish Gambino            10.021           10.022778
# 8          Death Grips            20.027           20.027036
# 13          Lil Yachty            20.055           20.058156
# 12         Erkin Koray            22.381           22.382317
# 4          Junior Boys            23.942           23.942602
# 14                 PNL            25.051           25.054687
# 16           New Order            26.140           26.140004
# 17          Funkadelic            27.647           27.647898
# 10      The Avalanches            38.111           38.111029
# 19            Le Youth            40.080           40.080002
# 11  Modern Folk Üçlüsü            45.740           45.740072
# 9          Honey Claws            50.068           50.068001
# 15     Crystal Castles            50.074           50.074001
# 3          Beach House            63.594           63.596772
# 5                Drake            65.039           65.039000
# 6                Drake            70.032           70.032000
# 2               Future            75.018           75.018004

# %% [markdown]
# # Interesting...

# %% [markdown]
# In the last plot above, it suddenly looks like **I've Seen Footage** is really *close* to Mask Off, and **One Night** is really *far* from Mask Off. But in our calculations of Euclidean distance above, both are ~20 units away from **Mask Off**. Can you guess what's wrong?

# %% [markdown]
# When we calculated the distance, the tempo was on a scale of 100's, while the acousticness was on a scale from 0 to 1. This means that the distance in tempo completely overshadowed the minute differences in acousticness.
#
# So, we need to make them both on the same ___.

# %% [markdown]
# ## Scaling Data

# %% [markdown]
# Also known as *normalizing* or standardizing data, we should scale our data to make our comparisons fair.

# %%
# Scale data to [0,1]
from sklearn.preprocessing import MinMaxScaler

# Scale tempo to [0,1]
tempo_column = dataset[['tempo']].values.astype(float)
tempo_scaler = MinMaxScaler().fit(tempo_column)
tempo_scaled = tempo_scaler.transform(tempo_column)
dataset['tempo_normalized'] = pandas.DataFrame(tempo_scaled)

# Scale acousticness to [0,1] (just in case)
acoustic_column = dataset[['acousticness']].values.astype(float)
acoustic_scaler = MinMaxScaler().fit(acoustic_column)
acousticness_scaled = acoustic_scaler.transform(acoustic_column)
dataset['acoustic_normalized'] = pandas.DataFrame(acousticness_scaled)

dataset
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 1   160.083       0.19900                               Redbone
# 2    75.044       0.03440                          Xanny Family
# 3    86.468       0.60400                        Master Of None
# 4   174.004       0.18000                        Parallel Lines
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 7   144.154       0.02020                       Gyöngyhajú lány
# 8   130.035       0.04810                     I've Seen Footage
# 9    99.994       0.00208                        Digital Animal
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 12  127.681       0.25300                               Cemalim
# 13  130.007       0.36600                             One Night
# 14  125.011       0.44000                               Oh lala
# 15   99.988       0.01900                                  Char
# 16  123.922       0.02390                       World In Motion
# 17  122.415       0.23300             One Nation Under a Groove
# 18  140.061       0.31400                               Bouncin
# 19  109.982       0.02420                  C O O L - Radio Edit
#
#                 artist  tempo_difference  euclidean_distance  \
# 0               Future             0.000            0.000000
# 1     Childish Gambino            10.021           10.022778
# 2               Future            75.018           75.018004
# 3          Beach House            63.594           63.596772
# 4          Junior Boys            23.942           23.942602
# 5                Drake            65.039           65.039000
# 6                Drake            70.032           70.032000
# 7                Omega             5.908            5.908008
# 8          Death Grips            20.027           20.027036
# 9          Honey Claws            50.068           50.068001
# 10      The Avalanches            38.111           38.111029
# 11  Modern Folk Üçlüsü            45.740           45.740072
# 12         Erkin Koray            22.381           22.382317
# 13          Lil Yachty            20.055           20.058156
# 14                 PNL            25.051           25.054687
# 15     Crystal Castles            50.074           50.074001
# 16           New Order            26.140           26.140004
# 17          Funkadelic            27.647           27.647898
# 18          Chief Keef            10.001           10.005613
# 19            Le Youth            40.080           40.080002
#
#     tempo_normalized  acoustic_normalized
# 0           0.758064             0.013490
# 1           0.859327             0.327153
# 2           0.000000             0.053695
# 3           0.115441             1.000000
# 4           1.000000             0.295587
# 5           0.100839             0.004502
# 6           0.050384             0.020634
# 7           0.698363             0.030104
# 8           0.555689             0.076455
# 9           0.252122             0.000000
# 10          0.372949             0.091574
# 11          0.295857             0.148558
# 12          0.531902             0.416866
# 13          0.555406             0.604599
# 14          0.504921             0.727539
# 15          0.252061             0.028110
# 16          0.493917             0.036251
# 17          0.478688             0.383639
# 18          0.657003             0.518208
# 19          0.353052             0.036749

# %%
# Now calculate the distances again using these normalized values
dataset['norm_euclidean_distance'] = numpy.sqrt( (0.011762 - dataset.acoustic_normalized)**2 
                                                + (0.748899 - dataset.tempo_normalized)**2)

# Sort the dataset from closest to farthest
sorted_dataset_distance = dataset.sort_values('norm_euclidean_distance')

# Display sorted dataset
sorted_dataset_distance
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 7   144.154       0.02020                       Gyöngyhajú lány
# 8   130.035       0.04810                     I've Seen Footage
# 16  123.922       0.02390                       World In Motion
# 1   160.083       0.19900                               Redbone
# 4   174.004       0.18000                        Parallel Lines
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 19  109.982       0.02420                  C O O L - Radio Edit
# 12  127.681       0.25300                               Cemalim
# 17  122.415       0.23300             One Nation Under a Groove
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 9    99.994       0.00208                        Digital Animal
# 15   99.988       0.01900                                  Char
# 18  140.061       0.31400                               Bouncin
# 13  130.007       0.36600                             One Night
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 2    75.044       0.03440                          Xanny Family
# 14  125.011       0.44000                               Oh lala
# 3    86.468       0.60400                        Master Of None
#
#                 artist  tempo_difference  acoustic_difference  \
# 0               Future             0.000              0.00000
# 7                Omega             5.908              0.01000
# 8          Death Grips            20.027              0.03790
# 16           New Order            26.140              0.01370
# 1     Childish Gambino            10.021              0.18880
# 4          Junior Boys            23.942              0.16980
# 10      The Avalanches            38.111              0.04700
# 19            Le Youth            40.080              0.01400
# 12         Erkin Koray            22.381              0.24280
# 17          Funkadelic            27.647              0.22280
# 11  Modern Folk Üçlüsü            45.740              0.08130
# 9          Honey Claws            50.068              0.00812
# 15     Crystal Castles            50.074              0.00880
# 18          Chief Keef            10.001              0.30380
# 13          Lil Yachty            20.055              0.35580
# 5                Drake            65.039              0.00541
# 6                Drake            70.032              0.00430
# 2               Future            75.018              0.02420
# 14                 PNL            25.051              0.42980
# 3          Beach House            63.594              0.59380
#
#     euclidean_distance  tempo_normalized  acoustic_normalized  \
# 0             0.000000          0.758064             0.013490
# 7             5.908008          0.698363             0.030104
# 8            20.027036          0.555689             0.076455
# 16           26.140004          0.493917             0.036251
# 1            10.022778          0.859327             0.327153
# 4            23.942602          1.000000             0.295587
# 10           38.111029          0.372949             0.091574
# 19           40.080002          0.353052             0.036749
# 12           22.382317          0.531902             0.416866
# 17           27.647898          0.478688             0.383639
# 11           45.740072          0.295857             0.148558
# 9            50.068001          0.252122             0.000000
# 15           50.074001          0.252061             0.028110
# 18           10.005613          0.657003             0.518208
# 13           20.058156          0.555406             0.604599
# 5            65.039000          0.100839             0.004502
# 6            70.032000          0.050384             0.020634
# 2            75.018004          0.000000             0.053695
# 14           25.054687          0.504921             0.727539
# 3            63.596772          0.115441             1.000000
#
#     norm_euclidean_distance
# 0                  0.009326
# 7                  0.053762
# 8                  0.203753
# 16                 0.256156
# 1                  0.334164
# 4                  0.378957
# 10                 0.384329
# 19                 0.396635
# 12                 0.459562
# 17                 0.459681
# 11                 0.473244
# 9                  0.496916
# 15                 0.497106
# 18                 0.514716
# 13                 0.623614
# 5                  0.648101
# 6                  0.698571
# 2                  0.750072
# 14                 0.756215
# 3                  1.173833

# %% [markdown]
# Now we can see the closest songs are different! Which are the most similar songs to Mask Off?

# %% [markdown]
# # Visualizing Our Data

# %% [markdown]
# We can start to see our data and notice that there are songs that are similar to Mask Off, but also very different!

# %%
# Now let's visualize that by plotting all the original data points
import matplotlib.pyplot as plot
plot.rcParams["figure.figsize"] = 8,8

plot.scatter(dataset['tempo_normalized'], dataset['acoustic_normalized'])
plot.xlabel('Tempo')
plot.ylabel('Acousticness')

plot.axis('equal')

for index, row in dataset.iterrows():
    plot.annotate(str(row['song_title']), xy=(row['tempo_normalized'], row['acoustic_normalized']))

# %% [markdown]
# Let's finish by visualizing even more songs from our database.

# %% [markdown]
# # Summary

# %% [markdown]
# Let's put everything together! And this time, let's use lots more data. 100 songs!
#
# **1. Pre-processing**
# - Reading the file
# - Getting the columns (features) we want
# - Choosing the rows (songs) we want
# - Scaling the features to [0,1]
#
# **2. Visualizing Data in Feature Space**
# - Plotting the songs in 2D space
#
# **3. Calculating Differences and Similarities**
# - Calculating distances and sorting them to find the most similar songs

# %%
import pandas
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plot

# Read the data from the spreadsheet
raw_data = pandas.read_csv('data/spotify.csv')  # Top 2017 songs of 2017 from kaggle.com

# Just get the columns we want
dataset = pandas.DataFrame(raw_data, columns = ['tempo', 'acousticness', 'song_title', 'artist'])

# Let's get the top 100 songs
dataset = dataset[:100]

# Scale tempo to [0,1]
tempo_column = dataset[['tempo']].values.astype(float)
tempo_scaler = MinMaxScaler().fit(tempo_column)
tempo_scaled = tempo_scaler.transform(tempo_column)
dataset['tempo_normalized'] = pandas.DataFrame(tempo_scaled)

# Scale acousticness to [0,1] (just in case)
acoustic_column = dataset[['acousticness']].values.astype(float)
acoustic_scaler = MinMaxScaler().fit(acoustic_column)
acousticness_scaled = acoustic_scaler.transform(acoustic_column)
dataset['acoustic_normalized'] = pandas.DataFrame(acousticness_scaled)\

# %%
# Now let's visualize that by plotting all the original data points
plot.rcParams["figure.figsize"] = 20,20

plot.scatter(dataset['tempo_normalized'], dataset['acoustic_normalized'])
plot.xlabel('Tempo')
plot.ylabel('Acousticness')

plot.axis('equal')

for index, row in dataset.iterrows():
    plot.annotate(str(row['song_title']), xy=(row['tempo_normalized'], row['acoustic_normalized']))

# %%
# Now calculate the distances again using these normalized values
import numpy
dataset['norm_euclidean_distance'] = numpy.sqrt( (0.011762 - dataset.acoustic_normalized)**2 
                                                + (0.748899 - dataset.tempo_normalized)**2)
# Sort the dataset from closest to farthest
sorted_dataset_distance = dataset.sort_values('norm_euclidean_distance')

# Display sorted dataset
sorted_dataset_distance
# Out:
#       tempo  acousticness                            song_title  \
# 0   150.062       0.01020                              Mask Off
# 7   144.154       0.02020                       Gyöngyhajú lány
# 8   130.035       0.04810                     I've Seen Footage
# 16  123.922       0.02390                       World In Motion
# 1   160.083       0.19900                               Redbone
# 4   174.004       0.18000                        Parallel Lines
# 10  111.951       0.05720  Subways - In Flagranti Extended Edit
# 19  109.982       0.02420                  C O O L - Radio Edit
# 12  127.681       0.25300                               Cemalim
# 17  122.415       0.23300             One Nation Under a Groove
# 11  104.322       0.09150            Donme Dolap - Baris K Edit
# 9    99.994       0.00208                        Digital Animal
# 15   99.988       0.01900                                  Char
# 18  140.061       0.31400                               Bouncin
# 13  130.007       0.36600                             One Night
# 5    85.023       0.00479                              Sneakin’
# 6    80.030       0.01450                           Childs Play
# 2    75.044       0.03440                          Xanny Family
# 14  125.011       0.44000                               Oh lala
# 3    86.468       0.60400                        Master Of None
#
#                 artist  tempo_difference  euclidean_distance  \
# 0               Future             0.000            0.000000
# 7                Omega             5.908            5.908008
# 8          Death Grips            20.027           20.027036
# 16           New Order            26.140           26.140004
# 1     Childish Gambino            10.021           10.022778
# 4          Junior Boys            23.942           23.942602
# 10      The Avalanches            38.111           38.111029
# 19            Le Youth            40.080           40.080002
# 12         Erkin Koray            22.381           22.382317
# 17          Funkadelic            27.647           27.647898
# 11  Modern Folk Üçlüsü            45.740           45.740072
# 9          Honey Claws            50.068           50.068001
# 15     Crystal Castles            50.074           50.074001
# 18          Chief Keef            10.001           10.005613
# 13          Lil Yachty            20.055           20.058156
# 5                Drake            65.039           65.039000
# 6                Drake            70.032           70.032000
# 2               Future            75.018           75.018004
# 14                 PNL            25.051           25.054687
# 3          Beach House            63.594           63.596772
#
#     tempo_normalized  acoustic_normalized  norm_euclidean_distance
# 0           0.758064             0.013490                 0.009326
# 7           0.698363             0.030104                 0.053762
# 8           0.555689             0.076455                 0.203753
# 16          0.493917             0.036251                 0.256156
# 1           0.859327             0.327153                 0.334164
# 4           1.000000             0.295587                 0.378957
# 10          0.372949             0.091574                 0.384329
# 19          0.353052             0.036749                 0.396635
# 12          0.531902             0.416866                 0.459562
# 17          0.478688             0.383639                 0.459681
# 11          0.295857             0.148558                 0.473244
# 9           0.252122             0.000000                 0.496916
# 15          0.252061             0.028110                 0.497106
# 18          0.657003             0.518208                 0.514716
# 13          0.555406             0.604599                 0.623614
# 5           0.100839             0.004502                 0.648101
# 6           0.050384             0.020634                 0.698571
# 2           0.000000             0.053695                 0.750072
# 14          0.504921             0.727539                 0.756215
# 3           0.115441             1.000000                 1.173833

# %% [markdown]
# # Your Turn!

# %% [markdown]
# Play with this a little bit -- find a song you like,
# and change the code above to find other songs in the top 100 songs that you might also like!

# %% [markdown]
# What can you say about the songs now that you've visualized it?

# %% [markdown]
# Can you try to add another feature? How would you modify the Euclidean Distance to accomodate another feature

# %% [markdown]
# # Discussion - Ethics and Bias in AI

# %% [markdown]
# What do you think about how features are chosen? Are all features equally important? Who chooses the features to use?
